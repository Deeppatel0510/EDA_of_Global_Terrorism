# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeppatel0510/EDA_of_Global_Terrorism/blob/main/Deep_EDA_Global_Terrorist_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -   GLOBAL TERRORISM DATASET [EDA]

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# #### The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.
# #Explore and analyze the data to discover key findings pertaining to terrorist activities.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### "Analyzing the Global Terrorism Database to identify patterns and trends in terrorist attacks over the past few decades. The goal is to identify the most significant factors that contribute to the likelihood and severity of terrorist attacks, such as geographic location, time of year, attack type, target type, and the affiliation and ideology of the perpetrators. This analysis aims to provide insights that can be used to develop effective counter-terrorism strategies to mitigate the impact of terrorism on individuals, societies, and nations."

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ## "The objective of this analysis is to provide valuable insights to government agencies, international organizations, and private companies that operate in areas affected by terrorism. By identifying the factors that contribute to the likelihood and severity of terrorist attacks, these stakeholders can better assess the risk of terrorist activity and develop more effective counter-terrorism strategies. This will help to improve public safety, reduce the economic impact of terrorism, and promote political stability in regions that have been affected by terrorist activity. Additionally, this analysis may be used by insurance companies, security firms, and other businesses that need to assess the risk of operating in high-risk areas."

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# # ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
 
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data = pd.read_csv('/content/Global Terrorism Data.csv', encoding='ISO-8859-1')
# Out:
# <ipython-input-43-cd6fd520f1ec>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/Global Terrorism Data.csv', encoding='ISO-8859-1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info(verbose =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 135 columns):
#  #    Column              Dtype
# ---   ------              -----
#  0    eventid             int64
#  1    iyear               int64
#  2    imonth              int64
#  3    iday                int64
#  4    approxdate          object
#  5    extended            int64
#  6    resolution          object
#  7    country             int64
#  8    country_txt         object
#  9    region              int64
#  10   region_txt          object
#  11   provstate           object
#  12   city                object
#  13   latitude            float64
#  14   longitude           float64
#  15   specificity         float64
#  16   vicinity            int64
#  17   location            object
#  18   summary             object
#  19   crit1               int64
#  20   crit2               int64
#  21   crit3               int64
#  22   doubtterr           float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
data.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# As the data set size is big enough and from data processing we found some the variables is not useful for our further data analysis and data visualization part so lets select only required columns and rename it and stored them in a new data frame for our further course of action.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Select only relevant columns which is help in data visulization and rename those columns in better format.
data.rename (columns = {'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                         'attacktype1_txt':'Attack_Type','target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary',
                         'gname':'Group','targtype1_txt':'Target_type','weaptype1_txt':'Weapon_type','motive':'Motive','success':'Success_rate'},inplace=True)

# %%
Final_data = data[['Year', 'Month', 'Day', 'Country', 'city', 'Region', 'Attack_Type', 'Target', 'Killed', 'Wounded', 'Summary', 'Group', 'Target_type', 'Weapon_type', 'Success_rate']]

# %%
Final_data.head()
# Out:
#    Year  Month  Day             Country           city  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
#
#                         Region                     Attack_Type  \
# 0  Central America & Caribbean                   Assassination
# 1                North America     Hostage Taking (Kidnapping)
# 2               Southeast Asia                   Assassination
# 3               Western Europe               Bombing/Explosion
# 4                    East Asia  Facility/Infrastructure Attack
#
#                     Target  Killed  Wounded Summary  \
# 0             Julio Guzman     1.0      0.0     NaN
# 1  Nadine Chaval, daughter     0.0      0.0     NaN
# 2                 Employee     1.0      0.0     NaN
# ...

# %%
# Dataset Describe
Final_data.describe().T
# Out:
#                  count         mean        std     min     25%     50%  \
# Year          181691.0  2002.638997  13.259430  1970.0  1991.0  2009.0
# Month         181691.0     6.467277   3.388303     0.0     4.0     6.0
# Day           181691.0    15.505644   8.814045     0.0     8.0    15.0
# Killed        171378.0     2.403272  11.545741     0.0     0.0     0.0
# Wounded       165380.0     3.167668  35.949392     0.0     0.0     0.0
# Success_rate  181691.0     0.889598   0.313391     0.0     1.0     1.0
#
#                  75%     max
# Year          2014.0  2017.0
# Month            9.0    12.0
# Day             23.0    31.0
# Killed           2.0  1570.0
# Wounded          2.0  8191.0
# Success_rate     1.0     1.0

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The "Final_data" variable consists of a subset of the original data, containing the following columns:
#
# *  Year:  The year in which the terrorist incident occurred.
# *  Month:  The month in which the terrorist incident occurred.
# *  Day:   The day of the month on which the terrorist incident occurred.
# *  Country:  The country where the terrorist incident took place.
# *  City: The city or location within the country where the terrorist incident occurred.
# *  Region: The region or area within the country where the terrorist incident took place.
# *  Attack_Type: The type of terrorist attack that was carried out.
# Target: The target or entity that was attacked.
# *  Killed: The number of individuals killed in the terrorist attack.
# Wounded: The number of individuals injured or wounded in the terrorist attack.
# *  Summary: A summary or brief description of the terrorist incident.
# *  Group: The terrorist group responsible for carrying out the attack.
# *  Target_type: The type of target that was attacked (e.g., civilians, government, military).
# *  Weapon_type: The type of weapon or method used in the terrorist attack.
# *  Success_rate: The success rate or outcome of the terrorist attack (e.g., successful, unsuccessful).
#
# This subset of data focuses on specific variables related to the year, month, day, location, attack details, casualties, summary, responsible group, target type, weapon type, and success rate. Analyzing this data can provide insights into patterns, trends, and characteristics of terrorist incidents.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
Final_data.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# city              434
# Region              0
# Attack_Type         0
# Target            636
# Killed          10313
# Wounded         16311
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Success_rate        0
# dtype: int64

# %%
# Filling the null values 
Final_data['city'].fillna('Unknown',inplace =True)

Final_data['Target'].fillna('Unknown',inplace =True)

Final_data['Killed'].fillna(0,inplace =True)
# Out:
# <ipython-input-54-11c16f53738f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_data['city'].fillna('Unknown',inplace =True)
# <ipython-input-54-11c16f53738f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_data['Target'].fillna('Unknown',inplace =True)
# <ipython-input-54-11c16f53738f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_data['Killed'].fillna(0,inplace =True)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Check Final Data info 
Final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Year          181691 non-null  int64
#  1   Month         181691 non-null  int64
#  2   Day           181691 non-null  int64
#  3   Country       181691 non-null  object
#  4   city          181691 non-null  object
#  5   Region        181691 non-null  object
#  6   Attack_Type   181691 non-null  object
#  7   Target        181691 non-null  object
#  8   Killed        181691 non-null  float64
#  9   Wounded       165380 non-null  float64
#  10  Summary       115562 non-null  object
#  11  Group         181691 non-null  object
#  12  Target_type   181691 non-null  object
#  13  Weapon_type   181691 non-null  object
#  14  Success_rate  181691 non-null  int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 20.8+ MB

# %%
# Write your code to make your dataset analysis ready.
Final_data.duplicated().sum()
# Out:
# 9591

# %%
# Check Final Data Shape.
Final_data.shape
# Out:
# (181691, 15)

# %%
# Check all columns included in Final Data.
Final_data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'city', 'Region', 'Attack_Type',
#        'Target', 'Killed', 'Wounded', 'Summary', 'Group', 'Target_type',
#        'Weapon_type', 'Success_rate'],
#       dtype='object')

# %%
# check all unique values in Final_data. 
Final_data.nunique()
# Out:
# Year                47
# Month               13
# Day                 32
# Country            205
# city             36674
# Region              12
# Attack_Type          9
# Target           86006
# Killed             205
# Wounded            238
# Summary         112492
# Group             3537
# Target_type         22
# Weapon_type         12
# Success_rate         2
# dtype: int64

# %%
# Years in the DataFrame
Final_data['Year'].unique()
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017])

# %%
# Count of each year in the Data Frame
Final_data['Year'].value_counts()
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# 1984     3495
# 1994     3456
# 2007     3242
# 1997     3197
# 1987     3183
# 1995     3081
# 1996     3058
# 1985     2915
# 1983     2870
# 1986     2860
# 2006     2758
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 2005     2017
# 2001     1906
# 2000     1814
# 1978     1526
# 1999     1395
# 2002     1333
# 1977     1319
# 2003     1278
# 2004     1166
# 1998      934
# 1976      923
# 1975      740
# 1970      651
# 1974      581
# 1972      568
# 1973      473
# 1971      471
# Name: Year, dtype: int64

# %% [markdown]
# As we see that from above year value_counts most attcked are done in 2014 to 2017. so it means that in those year terrorist groups are highly activated.

# %%
# Total Count of the regions in the DataFrame
Final_data['Region'].value_counts()
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %% [markdown]
# As expected Middle East & North Africa a.k.a MENA is most affected region over the world followed by South Asia.

# %%
# Total Count of the Terrorist_group in the DataFrame
Final_data['Group'].value_counts()
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
#                                                     ...
# Ansar Sarallah                                          1
# Sword of Islam                                          1
# Support of Ocalan-The Hawks of Thrace                   1
# Arab Revolutionary Front                                1
# MANO-D                                                  1
# Name: Group, Length: 3537, dtype: int64

# %% [markdown]
# Strange 82782 times no terrorist orgaisations take any responsibilities.

# %%
# Total Count of Attack_Type in the DataFrame
Final_data['Attack_Type'].value_counts()
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_Type, dtype: int64

# %% [markdown]
# From the above data we can see Bombing/Explosion is the main weapon used for any attack by the terrorist as it can do a large impact.
#
# Hijacking is the least attack type as all the government tightened the securitities at the Airport.

# %%
# Total Count of Target_type in the DataFrame
Final_data['Target_type'].value_counts()
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_type, dtype: int64

# %% [markdown]
# It's known to the everyone that Private Citizens & Property's are the main target for the terrorist groups do not know what they get by doing this as we all are lost our beloved ones

# %%
# Most attcked and least attacked in countries

most_attcked_country = Final_data['Country'].value_counts().head(1)
least_attcked_country = Final_data['Country'].value_counts().tail(1)

print(f'Most Attcked country is {most_attcked_country}')
print(f'Least Attcked country is {least_attcked_country}')
# Out:
# Most Attcked country is Iraq    24636
# Name: Country, dtype: int64
# Least Attcked country is Antigua and Barbuda    1
# Name: Country, dtype: int64

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### Chart - 1: Visualization of Number of Attacks by Region

# %%
# Set the size of the plot
plt.figure(figsize=(15, 7))

# Create a countplot of the 'Region' column in the 'Final_data' dataframe

Region_Attack = sns.countplot(y='Region', data=Final_data)
Region_Attack.bar_label(Region_Attack.containers[0])
# Rotate the x-tick labels by 90 degrees
plt.xticks(rotation=90)

# Set the y-axis label and font size
plt.ylabel('Region', fontsize=18)

# Set the x-axis label and font size
plt.xlabel('Count', fontsize=18)

# Set the title of the plot and font size
plt.title('Number of Attacks by Region Name', fontsize=24, weight='bold')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen because it effectively displays the frequency of terrorist attacks by region.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart show the number of attacks in each region, with the Middle East & North Africa being the most affected region, followed by South Asia.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can support businesses in making informed decisions regarding security measures, resource allocation, and risk management strategies.

# %% [markdown]
# ### Chart - 2 Trend of Number of Attacks Over Time

# %%
# Set the size of the plot
plt.figure(figsize=(20, 8))

# Group the data by year and count the number of attacks
attacks_by_year = Final_data.groupby('Year')['Year'].count()

# Create a line plot of the number of attacks over time
sns.lineplot(x=attacks_by_year.index, y=attacks_by_year.values)

# Set the x-axis label and font size
plt.xlabel('Year', fontsize=12)

# Set the y-axis label and font size
plt.ylabel('Number of Attacks', fontsize=12)

# Set the title of the plot and font size
plt.title('Number of Attacks Over Time', fontsize=12)

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot was chosen to visualize the trend of the number of attacks over time, allowing for easy observation of any patterns or changes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the overall trend of the number of attacks over time, indicating whether the frequency is increasing, decreasing, or fluctuating. This insight helps in understanding the changing nature of global terrorism.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights can aid in developing strategies for risk management, resource allocation, and security measures, enabling businesses to mitigate the impact of terrorist attacks and enhance safety.

# %% [markdown]
# ### Chart - 3 : Mode of Attacks: Distribution of Attack Types

# %%
# Set the size of the plot
plt.figure(figsize=(15,8))

# Create a countplot of the 'Attack_Type' column in the 'Final_data' dataframe
Attack_Type = sns.countplot(x= 'Attack_Type', data = Final_data)

Attack_Type.bar_label(Attack_Type.containers[0])

# Rotate the x-tick labels by 90 degrees
plt.xticks(rotation=90)

# Set the y-axis label and font size
plt.ylabel('Counts',fontsize=20)

# Set the x-axis label and font size
plt.xlabel('Attack Types',fontsize=20)

# Set the title of the plot and font size
plt.title('Mode of Attacks',fontsize=20, weight='bold')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was chosen as it effectively displays the frequency of each attack type, allowing for easy comparison and identification of the most common modes of attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights gained from the chart include the identification of the most common types of attacks and the trend of increasing attacks over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the insights can assist in understanding the prevalent attack types, enabling businesses to enhance security measures, allocate resources, and develop strategies to mitigate risks associated with specific attack types.

# %% [markdown]
# ### Chart - 4: Success Rate of Terrorist Attacks: Distribution as a Pie Chart

# %%
# renaming labels from numerics to string for proper naming convention
Final_data['Success_rate'] = Final_data['Success_rate'].map({0:'Unsuccessful Attempt', 1:'Successful Attempt'} )
# Out:
# <ipython-input-70-0c61b9f2d5a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Final_data['Success_rate'] = Final_data['Success_rate'].map({0:'Unsuccessful Attempt', 1:'Successful Attempt'} )

# %% [markdown]
# This code creates a pie chart to visualize the success rate of terrorist attacks.

# %%
# Set the figure size
plt.figure(figsize=(6,6))

# Plot the value counts of 'Success_rate' column as a pie chart
Final_data['Success_rate'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, fontsize=15)

# Set the title of the plot
plt.title('Success Rate of Terrorist Attacks', fontsize=16)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart was chosen to visualize the distribution of success rates for terrorist attacks, allowing for a clear representation of the proportion of successful and unsuccessful attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the distribution of success rates for terrorist attacks, indicating the percentage of successful and unsuccessful attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights can help businesses understand the success rates of terrorist attacks, enabling them to assess risks, allocate resources, and develop strategies to enhance security and mitigate the impact of such attacks.

# %% [markdown]
# ## Chart - 5 : Correlation Graph

# %%
# Correlation Graph
plt.figure(figsize=(10,5))
sns.heatmap(Final_data.corr(), annot=True)
# Out:
# <ipython-input-72-dd055ec7d9f3>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Final_data.corr(), annot=True)
# <Axes: >

# %% [markdown]
# This plot is used to investigate the dependence between multiple variables at the same time and to highlight the most correlated variables in a data table. In this visual, correlation coefficients are colored according to the value.

# %% [markdown]
# ###  Chart - 6 : Revealing the Country-wise Distribution of Attacks

# %%
# Set the figure size
plt.figure(figsize=(15, 7))

# Create a count plot using seaborn
Attack_Country_wise = sns.countplot(x='Country', data=Final_data, order=Final_data['Country'].value_counts().head(15).index, palette="colorblind" )
Attack_Country_wise.bar_label(Attack_Country_wise.containers[0])

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=90)

# Set the x-axis label
plt.xlabel('Country')

# Set the y-axis label
plt.ylabel('Number of Attacks')

# Set the plot title
plt.title('Number of Attacks Country Wise')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this specific chart to analyze the distribution of attacks across different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights obtained from the chart showcase the number of attacks in each country, highlighting the top 15 countries with the highest frequency of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These gained insights can potentially create a positive business impact by aiding in identifying high-risk areas and implementing targeted security measures accordingly.

# %% [markdown]
# ##   Chart - 7 : Unveiling Terrorist Use of Target Types

# %%
# Set the figure size
plt.figure(figsize=(15, 8))

# Create a count plot using seaborn with ordinary colors
Target_Type = sns.countplot(y='Target_type', data=Final_data, palette='Set3')
Target_Type.bar_label(Target_Type.containers[0])

# Set the x-axis label
plt.xlabel('Counts')

# Set the y-axis label
plt.ylabel('Target Type')

# Set the plot title
plt.title('Terrorist Use of Target Types')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I selected this specific chart to explore the distribution of terrorist attacks across various target types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that private citizens and property are the most targeted, followed by military and police. It also highlights the significant impact of terrorist attacks on transportation and government institutions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by enabling organizations and security agencies to prioritize security measures and allocate resources based on the most targeted types, enhancing overall preparedness and mitigating risks.

# %% [markdown]
# #   Chart - 8 : Analyzing the Top 15 Countries with the Highest Number of Killed Individuals

# %%
# Group the data by 'Country' and count the number of occurrences of 'Killed'
Kill_Country = Final_data.groupby('Country')['Killed'].sum()

# Select the top 15 countries with the highest number of occurrences
Top_Country = Kill_Country.sort_values(ascending=False).head(15)

# Define a color palette
colors = sns.color_palette('Blues_r', len(Top_Country))

# Plot the count plot with different colors
plt.figure(figsize=(15,8))
sns.barplot(x=Top_Country.index, y=Top_Country.values, palette=colors)
plt.xlabel('Country')
plt.ylabel('Number of Killed Individuals')
plt.title('Top 15 Countries with the Highest Number of Killed Individuals')
plt.xticks(rotation=90)

# Add annotations to the bars
for i, value in enumerate(Top_Country.values):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I chose this specific chart to examine the countries where the highest number of individuals have been killed due to various incidents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Iraq is the country with the highest number of killed individuals due to
# terrorism, followed by Afghanistan and Pakistan.
#
# * The number of killed individuals due to terrorism in Iraq is significantly higher than any other country.
#
# * The top 15 countries with the highest number of killed individuals due to terrorism are mostly from the Middle East and South Asia.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help in creating a positive business impact by emphasizing the need for enhanced security measures and strategic planning in high-risk countries, thereby mitigating potential risks and ensuring the safety of individuals and businesses operating in those regions.

# %% [markdown]
# ### Chart - 9 : Exploring Weapon Type Distribution

# %%
# Set the figure size
plt.figure(figsize=(8, 8))

# Get the value counts for 'Weapon_type' and plot the pie chart

# Custom color palette
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']  
Final_data['Weapon_type'].value_counts()[0:6].plot(kind='pie', autopct='%1.1f%%', colors=colors)

# Add a title if needed
plt.title("Weapon Type Distribution", fontsize=16)

# Remove the y-axis label
plt.ylabel('')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I selected this specific chart to analyze the distribution of weapon types used in various incidents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the proportionate distribution of weapon types, showcasing the percentage representation of each weapon type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by highlighting the prevalent weapon types used in incidents, enabling businesses to implement targeted security measures and allocate resources accordingly to address potential threats effectively.

# %% [markdown]
# # Chart - 10 : Analysis of Top 15 Countries by Number of Attacks and Total Kills

# %%
# Select the top 15 countries by number of attacks
attack = Final_data['Country'].value_counts().head(15).to_frame()

# Group the data by country and calculate the sum of kills, then select the top 15 countries
kill = Final_data.groupby('Country')['Killed'].sum().to_frame()

# Merge the attack and kill data based on the country index
merged_data = attack.merge(kill, left_index=True, right_index=True, how='left')

# Create a bar plot
ax = merged_data.plot.bar(width=0.9)

# Set the figure size
fig = plt.gcf()
fig.set_size_inches(16, 4)

# Set the title and labels for the plot
plt.title('Top 15 Countries by Number of Attacks and Total Kills', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I picked this specific chart to compare the number of attacks and the total number of kills in the top 15 countries, providing a comprehensive overview of their impact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals insights into the relationship between the number of attacks and the total number of kills in the top 15 countries. It allows for identifying countries with a high number of attacks but relatively lower total kills or vice versa.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by providing a better understanding of the security landscape in different countries. Businesses can utilize this information to assess risks, develop appropriate security measures, allocate resources effectively, and make informed decisions when expanding or operating in these countries.

# %% [markdown]
# # Chart - 11 Analyzing the Top 10 Terrorist Groups by Count

# %%
# Set the figure size
plt.figure(figsize=(15, 8))

# Create a countplot using seaborn
ax = sns.countplot(y='Group', data=Final_data, order=Final_data['Group'].value_counts()[1:10].index)

# Add labels to the bars
ax.bar_label(ax.containers[0])

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Set the title, x-axis label, and y-axis label for the plot
plt.title('Top 10 Terrorist Groups', fontsize=16)
plt.xlabel('Terrorist Group', fontsize=12)
plt.ylabel('Count', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose this specific chart to visualize and compare the count of terrorist groups, focusing on the top 10 groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the relative frequency of occurrence for each of the top 10 terrorist groups, allowing for easy comparison of their representation in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by enhancing understanding of the prominent terrorist groups, enabling businesses to tailor security measures, risk assessments, and contingency plans to effectively address potential threats and ensure the safety of operations and personnel.

# %% [markdown]
# ##  Chart - 12 : Analyzing Attack Frequency Distribution of Years in India

# %%
# Number of Attacks in India by Year
india = Final_data[Final_data['Country']== 'India']
number_of_attacks = india['Year'].value_counts()
number_of_attacks
# Out:
# 2016    1025
# 2017     966
# 2015     884
# 2014     860
# 2013     694
# 2009     672
# 2010     663
# 2011     645
# 2012     611
# 2008     534
# 1988     358
# 1990     349
# 1991     339
# 1989     324
# 1992     237
# 2001     234
# 1996     213
# 2003     196
# 1997     193
# 2002     184
# 2000     180
# 1995     179
# 2006     167
# 1987     166
# 1984     159
# 2007     149
# 2005     146
# 1999     112
# 2004     108
# 1994     107
# 1986      96
# 1998      61
# 1983      47
# 1985      39
# 1979      20
# 1981      16
# 1982      13
# 1980      10
# 1975       1
# 1977       1
# 1976       1
# 1972       1
# Name: Year, dtype: int64

# %%
# Set plot style
sns.set(style="whitegrid")

# Set figure size
fig, ax = plt.subplots(figsize=(15, 8))

# Create stem plot
x = india['Year'].unique()  # Unique years
y = india['Year'].value_counts().sort_index()  # Count of attacks per year
markerline, stemlines, baseline = ax.stem(x, y, linefmt='b-', markerfmt='bo', basefmt='r-')

# Adjust stem plot markers
markerline.set_markerfacecolor('b')
markerline.set_markeredgecolor('b')

# Rotate x-axis labels
plt.xticks(rotation=90)

# Set axis labels and title
ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.set_title('Attack Frequency Distribution of Years in India', fontsize=14)

# Remove spines
sns.despine()

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected this specific chart to examine the distribution of attack frequencies across different years in India.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the fluctuation of attack frequencies over the years in India, showcasing the variations and patterns in the occurrence of incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by enabling businesses to understand the historical trends and patterns of attacks, allowing them to devise appropriate security strategies and allocate resources effectively to mitigate risks and ensure the safety of operations in India.

# %% [markdown]
# ## Chart - 13 :  Exploring Top 10 Terrorist Groups in India by Total Number of Kills

# %%
# Analysis of Cities in India with the Highest Number of Kills
india.groupby('city')['Killed'].sum().nlargest().reset_index()
# Out:
#         city  Killed
# 0    Unknown  1458.0
# 1   Srinagar   769.0
# 2     Mumbai   474.0
# 3  New Delhi   378.0
# 4   Amritsar   376.0

# %%
# Set the figure size
plt.figure(figsize=(15, 8))

# Group the 'india' DataFrame by 'Group' and calculate the sum of 'Killed', then select the top 10 groups
data_ = india.groupby('Group')['Killed'].sum().nlargest(10)

# Create a horizontal bar plot using seaborn
Group = sns.barplot(y=data_.index, x=data_.values)

# Add labels to the bars
Group.bar_label(Group.containers[0])

# Set the title and labels for the plot
plt.title('Top 10 Terrorist Groups in India by Total Number of Kills', fontsize=16)
plt.xlabel('Number of Kills', fontsize=12)
plt.ylabel('Terrorist Group', fontsize=12)

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I selected this specific chart to analyze and compare the total number of kills attributed to the top 10 terrorist groups operating in India.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals insights into the most lethal terrorist groups in India, showcasing their respective counts of kills. It allows for a comparison of the impact and threat posed by these groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The gained insights can help create a positive business impact by providing a deeper understanding of the dominant terrorist groups in India, enabling businesses to tailor their security measures, risk assessments, and contingency plans to mitigate potential threats effectively and ensure the safety of operations and personnel.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve their business objectives in the context of global terrorism data, I suggest the following:
#
# *   Conduct a thorough risk assessment: Assess the specific risks and threats posed by terrorism in their operating regions and industry.
#
# *   Enhance security measures: Implement robust physical and digital security measures to mitigate potential disruptions.
#
# *   Diversify operations: Identify vulnerabilities in supply chains and business operations, and develop contingency plans to minimize the impact of terrorist activities.
#
# *  Stay informed: Continuously monitor and analyze global terrorism data to adapt strategies and security measures accordingly.
#
# *   Collaborate with stakeholders: Engage with relevant authorities and industry partners to exchange information and collaborate on security initiatives.
#
# *  By implementing these strategies, businesses can protect their assets, employees, and communities while working towards their business objectives in the face of global terrorism.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, global terrorist data provides valuable insights that can shape effective strategies and decisions in countering terrorism. By analyzing this data, businesses and organizations can enhance their risk assessments, fortify security measures, and proactively protect their assets and communities. It is crucial to prioritize the utilization of global terrorist data to create a safer environment and contribute to the global effort against terrorism.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
